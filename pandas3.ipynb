# %%
import pandas as pd

# %%
df_big = pd.read_csv('DataSets/Copy of BigmacBurger_data2.csv',parse_dates=['Date'],index_col=['Date','Country'])
df_big.head()
# Out:
#                   Price in US Dollars
# Date   Country
# Jan-16 Argentina                 2.39
#        Australia                 3.74
#        Brazil                    3.35
#        Britain                   4.22
#        Canada                    4.14

# %%
df_big.loc[('Jan-16')].loc["Australia":'Canada']
# Out:
#            Price in US Dollars
# Country
# Australia                 3.74
# Brazil                    3.35
# Britain                   4.22
# Canada                    4.14

# %%
df_big.loc[('Jan-16')]["Australia":'Canada']
# Out:
#            Price in US Dollars
# Country
# Australia                 3.74
# Brazil                    3.35
# Britain                   4.22
# Canada                    4.14

# %%
df_big.rename(index={'Date':'Country'})#,'Country':'Date'})
# Out:
#                       Price in US Dollars
# Date   Country
# Jan-16 Argentina                     2.39
#        Australia                     3.74
#        Brazil                        3.35
#        Britain                       4.22
#        Canada                        4.14
# ...                                   ...
# Jan-10 UAE                           2.99
#        Ukraine                       1.83
#        United States                 3.58
#        Uruguay                       3.32
#        Urgu                          3.32
#
# [653 rows x 1 columns]

# %%
df_big.index.get_level_values(1)
# Out:
# Index(['Argentina', 'Australia', 'Brazil', 'Britain', 'Canada', 'Chile',
#        'China', 'Colombia', 'Costa Rica', 'Czech Republic',
#        ...
#        'Sweden', 'Switzerland', 'Taiwan', 'Thailand', 'Turkey', 'UAE',
#        'Ukraine', 'United States', 'Uruguay', 'Urgu'],
#       dtype='object', name='Country', length=653)

# %%
df_big.transpose().loc[:,'Jan-16'].loc[:,'Argentina':'Canada']
# Out:
# Country              Argentina  Australia  Brazil  Britain  Canada
# Price in US Dollars       2.39       3.74    3.35     4.22    4.14

# %%
df_big_tr=df_big.transpose()
df_big_tr.loc['Country':,'Jan-16']
# Out:
# Country              Argentina  Australia  Brazil  Britain  Canada  Chile  \
# Price in US Dollars       2.39       3.74    3.35     4.22    4.14   2.94
#
# Country              China  Colombia  Costa Rica  Czech Republic  ...  \
# Price in US Dollars   2.68      2.43        4.02            2.98  ...
#
# Country              Estonia  Finland  France  Germany  Greece  Ireland  \
# Price in US Dollars     3.23     4.41    4.41     3.86     3.6     4.25
#
# Country              Italy  Netherlands  Portugal  Spain
# Price in US Dollars    4.3         3.71      3.23   3.76
#
# [1 rows x 56 columns]

# %%
df_big_tr['Jan-16'].loc[:,'Australia':'Canada']
# df_big_tr.loc[:,('Jan-16','Argentina'):('Jan-16','Chile')]
# Out:
# Country              Australia  Brazil  Britain  Canada
# Price in US Dollars       3.74    3.35     4.22    4.14

# %%
df_big_tr.columns
# Out:
# MultiIndex([('Jan-16',      'Argentina'),
#             ('Jan-16',      'Australia'),
#             ('Jan-16',         'Brazil'),
#             ('Jan-16',        'Britain'),
#             ('Jan-16',         'Canada'),
#             ('Jan-16',          'Chile'),
#             ('Jan-16',          'China'),
#             ('Jan-16',       'Colombia'),
#             ('Jan-16',     'Costa Rica'),
#             ('Jan-16', 'Czech Republic'),
#             ...
#             ('Jan-10',         'Sweden'),
#             ('Jan-10',    'Switzerland'),
#             ('Jan-10',         'Taiwan'),
#             ('Jan-10',       'Thailand'),
#             ('Jan-10',         'Turkey'),
#             ('Jan-10',            'UAE'),
#             ('Jan-10',        'Ukraine'),
#             ('Jan-10',  'United States'),
#             ('Jan-10',        'Uruguay'),
#             ('Jan-10',           'Urgu')],
#            names=['Date', 'Country'], length=653)

# %%
df_big = pd.read_csv('DataSets/Copy of BigmacBurger_data2.csv',parse_dates=['Date'],index_col=['Date'])
df_big.head()
# Out:
#           Country  Price in US Dollars
# Date
# Jan-16  Argentina                 2.39
# Jan-16  Australia                 3.74
# Jan-16     Brazil                 3.35
# Jan-16    Britain                 4.22
# Jan-16     Canada                 4.14

# %%
df_big.index
# Out:
# Index(['Jan-16', 'Jan-16', 'Jan-16', 'Jan-16', 'Jan-16', 'Jan-16', 'Jan-16',
#        'Jan-16', 'Jan-16', 'Jan-16',
#        ...
#        'Jan-10', 'Jan-10', 'Jan-10', 'Jan-10', 'Jan-10', 'Jan-10', 'Jan-10',
#        'Jan-10', 'Jan-10', 'Jan-10'],
#       dtype='object', name='Date', length=653)

# %%
# df_big.loc['Jan-16'].stack()
df_big.stack()
# Out:
# Date
# Jan-16  Country                Argentina
#         Price in US Dollars         2.39
#         Country                Australia
#         Price in US Dollars         3.74
#         Country                   Brazil
#                                  ...
# Jan-10  Price in US Dollars         3.58
#         Country                  Uruguay
#         Price in US Dollars         3.32
#         Country                     Urgu
#         Price in US Dollars         3.32
# Length: 1306, dtype: object

# %%
df_big.unstack(level=0)
# Out:
#                      Date
# Country              Jan-16    Argentina
#                      Jan-16    Australia
#                      Jan-16       Brazil
#                      Jan-16      Britain
#                      Jan-16       Canada
#                                  ...
# Price in US Dollars  Jan-10         2.99
#                      Jan-10         1.83
#                      Jan-10         3.58
#                      Jan-10         3.32
#                      Jan-10         3.32
# Length: 1306, dtype: object

# %%
df_big.pivot(columns='Country')
# Out:
#         Price in US Dollars                                                  \
# Country           Argentina Australia Austria Belgium Brazil Britain Canada
# Date
# Jan-10                 1.84      3.98     NaN     NaN   4.76    3.67   3.97
# Jan-12                 4.64      4.94    3.92    4.69   5.68    3.82   4.63
# Jan-13                 3.82      4.90    4.60    5.16   5.64    4.25   5.39
# Jan-14                 3.03      4.47    4.60    5.36   5.25    4.63   5.01
# Jan-15                 3.25      4.32    3.93    4.29   5.21    4.37   4.64
# Jan-16                 2.39      3.74    3.76    4.25   3.35    4.22   4.14
# Jul-10                 3.56      3.84     NaN     NaN   4.91    3.48   4.00
# Jul-11                 4.84      4.94    4.43    5.38   6.16    3.89   5.00
# Jul-12                 4.16      4.68    3.87    4.61   4.94    4.16   5.02
# Jul-13                 3.88      4.62    4.36    4.76   5.28    4.02   5.26
# ...

# %%
# create pivot using team as col, first name as indx, sal as val

df_emp = pd.read_csv('DataSets/EmployeesInfo.csv')
df_emp.head()
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 1     Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 2      Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 3      Jerry    Male   3/4/2005         1:00 PM  138705    9.340
# 4      Larry    Male  1/24/1998         4:47 PM  101004    1.389
#
#   Senior Management             Team
# 0              True        Marketing
# 1              True              NaN
# 2             False          Finance
# 3              True          Finance
# 4              True  Client Services

# %%
df_emp = df_emp.drop_duplicates(subset=['First Name'], keep='first')
df_emp =df_emp.dropna()

# %%
df_emp.pivot(columns=['Team'],index='First Name',values='Salary')
# Out:
# Team        Business Development  Client Services  Distribution  Engineering  \
# First Name
# Aaron                        NaN              NaN           NaN          NaN
# Adam                         NaN              NaN       95327.0          NaN
# Albert                       NaN              NaN           NaN      67827.0
# Alice                        NaN              NaN           NaN          NaN
# Amanda                       NaN              NaN       80803.0          NaN
# ...                          ...              ...           ...          ...
# Walter                       NaN              NaN           NaN          NaN
# Wanda                        NaN              NaN           NaN          NaN
# Wayne                        NaN              NaN      102652.0          NaN
# William                      NaN              NaN           NaN          NaN
# Willie                       NaN              NaN           NaN          NaN
#
# ...

# %%
df_emp.pivot(columns='First Name',index=['Team'],values='Salary').fillna('')
# Out:
# First Name              Aaron     Adam   Albert    Alice   Amanda       Amy  \
# Team
# Business Development
# Client Services
# Distribution                   95327.0                    80803.0
# Engineering                             67827.0                    122897.0
# Finance                                          51395.0
# Human Resources
# Legal
# Marketing             61602.0
# Product
# Sales
#
# First Name              Andrea   Andrew   Angela      Ann  ...     Terry  \
# Team                                                       ...
# Business Development  120204.0                    90719.0  ...
# Client Services                 43414.0                    ...  124008.0
# Distribution                                               ...
# Engineering                              95570.0           ...
# Finance                                                    ...
# Human Resources                                            ...
# ...

# %%
df_uf = pd.read_csv('DataSets/userfoods.csv')
df_uf.head()
# Out:
#   First Name  Gender          City Frequency       Item  Spend
# 0      Wanda  Female      Stamford    Weekly     Burger  15.66
# 1       Eric    Male      Stamford     Daily    Chalupa  10.56
# 2    Charles    Male      New York     Never      Sushi  42.14
# 3       Anna  Female  Philadelphia      Once  Ice Cream  11.01
# 4    Deborah  Female  Philadelphia     Daily    Chalupa  23.49

# %%
df_uf.pivot_table(index='City', columns='Frequency', values='Spend',aggfunc=sum)
# Out:
# Frequency       Daily  Monthly    Never    Often     Once   Seldom   Weekly  \
# City
# New York      2595.22  2358.57  1471.69  1938.69  1693.50  1698.49  2257.71
# Philadelphia  2523.96  1937.61  2763.40  1995.44  2298.81  2257.49  2129.50
# Stamford      1857.67  1709.39  1903.07  2423.31  1930.01  1529.38  2876.35
#
# Frequency      Yearly
# City
# New York      1795.70
# Philadelphia  1928.33
# Stamford      2196.08

# %%
df_uf.pivot_table(index='Gender',values='Spend', aggfunc=sum)
# Out:
#            Spend
# Gender
# Female  25963.33
# Male    24106.04

# %%
df_uf.pivot_table(index=['Item'], values=['Spend','City'],aggfunc=[sum])
# Out:
#                sum
#              Spend
# Item
# Burger     7765.73
# Burrito    8270.44
# Chalupa    7644.52
# Donut      8758.76
# Ice Cream  8886.99
# Sushi      8742.93

# %%
# df_uf.pivot_table(index=['Item','City'], values=['Spend'],aggfunc=[sum])

# %%
df_uf.groupby(['Item','City'])['Spend'].sum().transpose()
# Out:
# Item       City
# Burger     New York        2533.13
#            Philadelphia    2577.42
#            Stamford        2655.18
# Burrito    New York        2378.35
#            Philadelphia    2771.69
#            Stamford        3120.40
# Chalupa    New York        2104.35
#            Philadelphia    2787.56
#            Stamford        2752.61
# Donut      New York        2792.05
#            Philadelphia    2888.62
#            Stamford        3078.09
# Ice Cream  New York        3125.25
#            Philadelphia    3670.49
#            Stamford        2091.25
# Sushi      New York        2876.44
#            Philadelphia    3138.76
#            Stamford        2727.73
# Name: Spend, dtype: float64

# %%
df_fort = pd.read_csv('DataSets/fortune_data.csv')
df_fort.head()
# Out:
#    Rank             Company       Sector  \
# 0     1             Walmart    Retailing
# 1     2         Exxon Mobil       Energy
# 2     3               Apple   Technology
# 3     4  Berkshire Hathaway   Financials
# 4     5            McKesson  Health Care
#
#                                    Industry           Location  Revenue  \
# 0                     General Merchandisers    Bentonville, AR   482130
# 1                        Petroleum Refining         Irving, TX   246204
# 2               Computers, Office Equipment      Cupertino, CA   233715
# 3  Insurance: Property and Casualty (Stock)          Omaha, NE   210821
# 4                  Wholesalers: Health Care  San Francisco, CA   181241
#
#    Profits  Employees
# 0    14694    2300000
# 1    16150      75600
# 2    53394     110000
# 3    24083     331000
# 4     1476      70400

# %%
df_fort.groupby('Sector').first()
# Out:
#                               Rank                 Company  \
# Sector
# Aerospace & Defense             24                  Boeing
# Apparel                         91                    Nike
# Business Services              144           ManpowerGroup
# Chemicals                       56            Dow Chemical
# Energy                           2             Exxon Mobil
# Engineering & Construction     155                   Fluor
# Financials                       4      Berkshire Hathaway
# Food and Drug Stores             7              CVS Health
# Food, Beverages & Tobacco       41  Archer Daniels Midland
# Health Care                      5                McKesson
# Hotels, Resturants & Leisure   109              McDonald’s
# Household Products              34        Procter & Gamble
# Industrials                     11        General Electric
# Materials                      126                   Alcoa
# Media                           53                  Disney
# ...

# %%
df_fort.groupby('Sector').last()
# Out:
#                               Rank                            Company  \
# Sector
# Aerospace & Defense            987              Delta Tucker Holdings
# Apparel                        917                              Guess
# Business Services              993              DeVry Education Group
# Chemicals                      949                        H.B. Fuller
# Energy                         997          Portland General Electric
# Engineering & Construction     994                       MDC Holdings
# Financials                     996         New York Community Bancorp
# Food and Drug Stores           928                             Fred’s
# Food, Beverages & Tobacco      954         Alliance One International
# Health Care                    978                 Providence Service
# Hotels, Resturants & Leisure   999                            Wendy’s
# Household Products             992                             Revlon
# ...

# %%
# max profit -> energy sector
df_fort[df_fort['Sector'] == 'Energy']['Profits'].max()
# Out:
# 16150

# %%
df_fort[df_fort['Sector'] == 'Energy']['Profits'].sort_values(ascending=False).iloc[0]
# Out:
# 16150

# %%
df_fort.groupby('Sector').get_group('Energy')['Profits'].max()
# Out:
# 16150

# %%
df_fort.groupby('Sector').min()
# Out:
#                               Rank                        Company  \
# Sector
# Aerospace & Defense             24                  B/E Aerospace
# Apparel                         91                       Carter’s
# Business Services              144                 ABM Industries
# Chemicals                       56                    A. Schulman
# Energy                           2                            AES
# Engineering & Construction     155                          AECOM
# Financials                       4                            AIG
# Food and Drug Stores             7                     CVS Health
# Food, Beverages & Tobacco       41     Alliance One International
# Health Care                      5                         AbbVie
# Hotels, Resturants & Leisure   109                Bloomin’ Brands
# Household Products              34                  Avon Products
# Industrials                     11                             3M
# ...

# %%
df_fort.groupby('Sector')['Profits'].max()
# Out:
# Sector
# Aerospace & Defense              7608
# Apparel                          3273
# Business Services                6328
# Chemicals                        7685
# Energy                          16150
# Engineering & Construction        803
# Financials                      24442
# Food and Drug Stores             5237
# Food, Beverages & Tobacco        7351
# Health Care                     18108
# Hotels, Resturants & Leisure     5920
# Household Products               7036
# Industrials                      4833
# Materials                         991
# Media                            8382
# Motor Vehicles & Parts           9687
# Retailing                       14694
# Technology                      53394
# Telecommunications              17879
# Transportation                   7610
# Wholesalers                      1472
# Name: Profits, dtype: int64

# %%
# avg emp for ad and marketing industry

df_fort[df_fort['Industry'] == 'Advertising, marketing']['Employees'].mean()
# Out:
# 62050.0

# %%
temp_fort = df_fort.groupby(['Sector','Industry'])#.get_group(('Energy','Petroleum Refining'))

# %%
temp_fort.get_group(('Energy','Petroleum Refining'))
# Out:
#      Rank                              Company  Sector            Industry  \
# 1       2                          Exxon Mobil  Energy  Petroleum Refining
# 13     14                              Chevron  Energy  Petroleum Refining
# 29     30                          Phillips 66  Energy  Petroleum Refining
# 31     32                        Valero Energy  Energy  Petroleum Refining
# 41     42                   Marathon Petroleum  Energy  Petroleum Refining
# 97     98                               Tesoro  Energy  Petroleum Refining
# 213   214                        HollyFrontier  Energy  Petroleum Refining
# 216   217                           PBF Energy  Energy  Petroleum Refining
# 288   289                     Western Refining  Energy  Petroleum Refining
# 393   394                                 Hess  Energy  Petroleum Refining
# 444   445                    Delek US Holdings  Energy  Petroleum Refining
# ...

# %%
df_fort.groupby('Sector').agg({'Profits':max,'Employees':min})
# Out:
#                               Profits  Employees
# Sector
# Aerospace & Defense              7608       6955
# Apparel                          3273       5978
# Business Services                6328       2400
# Chemicals                        7685       1979
# Energy                          16150        480
# Engineering & Construction        803       1036
# Financials                      24442        187
# Food and Drug Stores             5237       1616
# Food, Beverages & Tobacco        7351       1857
# Health Care                     18108       2924
# Hotels, Resturants & Leisure     5920       8500
# Household Products               7036       4406
# Industrials                      4833       4104
# Materials                         991         52
# Media                            8382       2341
# Motor Vehicles & Parts           9687       2700
# Retailing                       14694       2155
# Technology                      53394       2285
# ...

# %%
df_fort2 = pd.read_csv('DataSets/fortune_data.csv')
df_fort2.head()
# Out:
#    Rank             Company       Sector  \
# 0     1             Walmart    Retailing
# 1     2         Exxon Mobil       Energy
# 2     3               Apple   Technology
# 3     4  Berkshire Hathaway   Financials
# 4     5            McKesson  Health Care
#
#                                    Industry           Location  Revenue  \
# 0                     General Merchandisers    Bentonville, AR   482130
# 1                        Petroleum Refining         Irving, TX   246204
# 2               Computers, Office Equipment      Cupertino, CA   233715
# 3  Insurance: Property and Casualty (Stock)          Omaha, NE   210821
# 4                  Wholesalers: Health Care  San Francisco, CA   181241
#
#    Profits  Employees
# 0    14694    2300000
# 1    16150      75600
# 2    53394     110000
# 3    24083     331000
# 4     1476      70400

# %%
pd.concat([df_fort2,df_fort],ignore_index=True)
# Out:
#       Rank                     Company                        Sector  \
# 0        1                     Walmart                     Retailing
# 1        2                 Exxon Mobil                        Energy
# 2        3                       Apple                    Technology
# 3        4          Berkshire Hathaway                    Financials
# 4        5                    McKesson                   Health Care
# ...    ...                         ...                           ...
# 1995   996  New York Community Bancorp                    Financials
# 1996   997   Portland General Electric                        Energy
# 1997   997   Portland General Electric                        Energy
# 1998   999                     Wendy’s  Hotels, Resturants & Leisure
# 1999  1000           Briggs & Stratton                   Industrials
#
#                                       Industry           Location  Revenue  \
# ...

# %%
df_fort.merge(df_fort2,)
# Out:
#       Rank                    Company                        Sector  \
# 0        1                    Walmart                     Retailing
# 1        2                Exxon Mobil                        Energy
# 2        3                      Apple                    Technology
# 3        4         Berkshire Hathaway                    Financials
# 4        5                   McKesson                   Health Care
# ...    ...                        ...                           ...
# 1003   997  Portland General Electric                        Energy
# 1004   997  Portland General Electric                        Energy
# 1005   997  Portland General Electric                        Energy
# 1006   999                    Wendy’s  Hotels, Resturants & Leisure
# 1007  1000          Briggs & Stratton                   Industrials
#
#                                       Industry           Location  Revenue  \
# ...

# %%
df_fort.append(df_fort2)
# Out:
# C:\Users\miles.MILE-BL-4766-LA.000\AppData\Local\Temp\ipykernel_4136\1729111210.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_fort.append(df_fort2)
#      Rank                     Company                        Sector  \
# 0       1                     Walmart                     Retailing
# 1       2                 Exxon Mobil                        Energy
# 2       3                       Apple                    Technology
# 3       4          Berkshire Hathaway                    Financials
# 4       5                    McKesson                   Health Care
# ..    ...                         ...                           ...
# 995   996  New York Community Bancorp                    Financials
# 996   997   Portland General Electric                        Energy
# 997   997   Portland General Electric                        Energy
# ...

# %%
df_movie = pd.read_csv('DataSets/movies.csv')
df_movie
# Out:
#       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9737   193581  Black Butler: Book of the Atlantic (2017)
# 9738   193583               No Game No Life: Zero (2017)
# 9739   193585                               Flint (2017)
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 1                      Adventure|Children|Fantasy
# 2                                  Comedy|Romance
# 3                            Comedy|Drama|Romance
# ...

# %%
df_rating = pd.read_csv('DataSets/ratings.csv')
df_rating
# Out:
#         userId  movieId  rating   timestamp
# 0            1        1     4.0   964982703
# 1            1        3     4.0   964981247
# 2            1        6     4.0   964982224
# 3            1       47     5.0   964983815
# 4            1       50     5.0   964982931
# ...        ...      ...     ...         ...
# 100831     610   166534     4.0  1493848402
# 100832     610   168248     5.0  1493850091
# 100833     610   168250     5.0  1494273047
# 100834     610   168252     5.0  1493846352
# 100835     610   170875     3.0  1493846415
#
# [100836 rows x 4 columns]

# %%
df_movie.merge(df_rating)
# Out:
#         movieId                                      title  \
# 0             1                           Toy Story (1995)
# 1             1                           Toy Story (1995)
# 2             1                           Toy Story (1995)
# 3             1                           Toy Story (1995)
# 4             1                           Toy Story (1995)
# ...         ...                                        ...
# 100831   193581  Black Butler: Book of the Atlantic (2017)
# 100832   193583               No Game No Life: Zero (2017)
# 100833   193585                               Flint (2017)
# 100834   193587        Bungo Stray Dogs: Dead Apple (2018)
# 100835   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                              genres  userId  rating  \
# 0       Adventure|Animation|Children|Comedy|Fantasy       1     4.0
# 1       Adventure|Animation|Children|Comedy|Fantasy       5     4.0
# ...

# %%
df_movie.merge(df_rating)[['movieId','userId','title']]
# Out:
#         movieId  userId                                      title
# 0             1       1                           Toy Story (1995)
# 1             1       5                           Toy Story (1995)
# 2             1       7                           Toy Story (1995)
# 3             1      15                           Toy Story (1995)
# 4             1      17                           Toy Story (1995)
# ...         ...     ...                                        ...
# 100831   193581     184  Black Butler: Book of the Atlantic (2017)
# 100832   193583     184               No Game No Life: Zero (2017)
# 100833   193585     184                               Flint (2017)
# 100834   193587     184        Bungo Stray Dogs: Dead Apple (2018)
# 100835   193609     331        Andrew Dice Clay: Dice Rules (1991)
#
# [100836 rows x 3 columns]

# %%
df_movie = df_movie.rename(columns={'movieId':'movie_id'})

# %%
df_tags = pd.read_csv('DataSets/tags.csv')
df_tags
# Out:
#       userId  movieId               tag   timestamp
# 0          2    60756             funny  1445714994
# 1          2    60756   Highly quotable  1445714996
# 2          2    60756      will ferrell  1445714992
# 3          2    89774      Boxing story  1445715207
# 4          2    89774               MMA  1445715200
# ...      ...      ...               ...         ...
# 3678     606     7382         for katie  1171234019
# 3679     606     7936           austere  1173392334
# 3680     610     3265            gun fu  1493843984
# 3681     610     3265  heroic bloodshed  1493843978
# 3682     610   168248  Heroic Bloodshed  1493844270
#
# [3683 rows x 4 columns]

# %%
df_movie.merge(df_rating,left_on='movie_id',right_on='movieId').merge(df_tags,left_on=['movie_id','userId'],right_on=['movieId','userId'])[['movie_id','title','tag','userId']].sort_values('userId')
# Out:
#       movie_id                                    title                tag  \
# 3160    106782          Wolf of Wall Street, The (2013)  Leonardo DiCaprio
# 3161    106782          Wolf of Wall Street, The (2013)    Martin Scorsese
# 2769     60756                     Step Brothers (2008)       will ferrell
# 3159    106782          Wolf of Wall Street, The (2013)              drugs
# 2768     60756                     Step Brothers (2008)    Highly quotable
# ...        ...                                      ...                ...
# 1565      3578                         Gladiator (2000)             Romans
# 2281      7382  I'm Not Scared (Io non ho paura) (2003)          for katie
# 3427    168248            John Wick: Chapter Two (2017)   Heroic Bloodshed
# 1476      3265    Hard-Boiled (Lat sau san taam) (1992)             gun fu
# 1477      3265    Hard-Boiled (Lat sau san taam) (1992)   heroic bloodshed
#
#       userId
# 3160       2
# 3161       2
# 2769       2
# ...

# %%
df_tags['userId'].nunique(),df_tags['movieId'].nunique()
# Out:
# (58, 1572)

# %%
df_rating['userId'].nunique(),df_rating['movieId'].nunique()
# Out:
# (610, 9724)

# %%
df_tags['movieId'].isin(df_rating['movieId'].unique()).sum()
# Out:
# 3662

# %%
df_rating.merge(df_tags,left_on=['movieId','userId'],right_on=['movieId','userId'])[['movieId','tag','userId']].sort_values('userId')
# Out:
#       movieId                tag  userId
# 0       60756              funny       2
# 7      106782  Leonardo DiCaprio       2
# 6      106782              drugs       2
# 5       89774          Tom Hardy       2
# 8      106782    Martin Scorsese       2
# ...       ...                ...     ...
# 3471     6107       World War II     606
# 3472     7382          for katie     606
# 3474     3265   heroic bloodshed     610
# 3473     3265             gun fu     610
# 3475   168248   Heroic Bloodshed     610
#
# [3476 rows x 3 columns]

# %%
df_rating.merge(df_tags,left_on=['movieId','userId'],right_on=['movieId','userId'],how='inner',indicator=True)
# Out:
#       userId  movieId  rating  timestamp_x               tag  timestamp_y  \
# 0          2    60756     5.0   1445714980             funny   1445714994
# 1          2    60756     5.0   1445714980   Highly quotable   1445714996
# 2          2    60756     5.0   1445714980      will ferrell   1445714992
# 3          2    89774     5.0   1445715189      Boxing story   1445715207
# 4          2    89774     5.0   1445715189               MMA   1445715200
# ...      ...      ...     ...          ...               ...          ...
# 3471     606     6107     4.0   1171324428      World War II   1178473747
# 3472     606     7382     4.5   1171233924         for katie   1171234019
# 3473     610     3265     5.0   1479542010            gun fu   1493843984
# 3474     610     3265     5.0   1479542010  heroic bloodshed   1493843978
# 3475     610   168248     5.0   1493850091  Heroic Bloodshed   1493844270
#
#      _merge
# 0      both
# 1      both
# 2      both
# 3      both
# ...

# %%
df_rating.merge(df_tags,left_on=['movieId','userId'],right_on=['movieId','userId'],how='left',indicator=True)
# Out:
#         userId  movieId  rating  timestamp_x               tag   timestamp_y  \
# 0            1        1     4.0    964982703               NaN           NaN
# 1            1        3     4.0    964981247               NaN           NaN
# 2            1        6     4.0    964982224               NaN           NaN
# 3            1       47     5.0    964983815               NaN           NaN
# 4            1       50     5.0    964982931               NaN           NaN
# ...        ...      ...     ...          ...               ...           ...
# 102672     610   166534     4.0   1493848402               NaN           NaN
# 102673     610   168248     5.0   1493850091  Heroic Bloodshed  1.493844e+09
# 102674     610   168250     5.0   1494273047               NaN           NaN
# 102675     610   168252     5.0   1493846352               NaN           NaN
# 102676     610   170875     3.0   1493846415               NaN           NaN
#
#            _merge
# 0       left_only
# ...

# %%
df_rating.merge(df_tags,left_on=['movieId','userId'],right_on=['movieId','userId'],how='right',indicator=True)
# Out:
#       userId  movieId  rating   timestamp_x               tag  timestamp_y  \
# 0          2    60756     5.0  1.445715e+09             funny   1445714994
# 1          2    60756     5.0  1.445715e+09   Highly quotable   1445714996
# 2          2    60756     5.0  1.445715e+09      will ferrell   1445714992
# 3          2    89774     5.0  1.445715e+09      Boxing story   1445715207
# 4          2    89774     5.0  1.445715e+09               MMA   1445715200
# ...      ...      ...     ...           ...               ...          ...
# 3678     606     7382     4.5  1.171234e+09         for katie   1171234019
# 3679     606     7936     NaN           NaN           austere   1173392334
# 3680     610     3265     5.0  1.479542e+09            gun fu   1493843984
# 3681     610     3265     5.0  1.479542e+09  heroic bloodshed   1493843978
# 3682     610   168248     5.0  1.493850e+09  Heroic Bloodshed   1493844270
#
#           _merge
# 0           both
# 1           both
# ...

# %%
df_rating.merge(df_tags,left_on=['movieId','userId'],right_on=['movieId','userId'],how='outer',indicator=True,suffixes=['_ratng','_tags'])
# Out:
#         userId  movieId  rating  timestamp_ratng          tag  timestamp_tags  \
# 0            1        1     4.0      964982703.0          NaN             NaN
# 1            1        3     4.0      964981247.0          NaN             NaN
# 2            1        6     4.0      964982224.0          NaN             NaN
# 3            1       47     5.0      964983815.0          NaN             NaN
# 4            1       50     5.0      964982931.0          NaN             NaN
# ...        ...      ...     ...              ...          ...             ...
# 102879     573     6016     NaN              NaN     not seen    1.186589e+09
# 102880     573     6157     NaN              NaN          bad    1.186589e+09
# 102881     573     6157     NaN              NaN  Ben Affleck    1.186589e+09
# 102882     600      273     NaN              NaN       gothic    1.237739e+09
# 102883     606     7936     NaN              NaN      austere    1.173392e+09
#
#             _merge
# ...

# %%
# time series

# %%
import datetime as dt

# %%
dt.datetime(1998,6,9)
# Out:
# datetime.datetime(1998, 6, 9, 0, 0)

# %%
pd.Timestamp('2013-1-3')
# Out:
# Timestamp('2013-01-03 00:00:00')

# %%
dt.datetime.now()
# Out:
# datetime.datetime(2023, 2, 2, 17, 7, 36, 685934)

# %%
pd.date_range(start='2023-02-1', end='2023-02-20',freq='D')
# Out:
# DatetimeIndex(['2023-02-01', '2023-02-02', '2023-02-03', '2023-02-04',
#                '2023-02-05', '2023-02-06', '2023-02-07', '2023-02-08',
#                '2023-02-09', '2023-02-10', '2023-02-11', '2023-02-12',
#                '2023-02-13', '2023-02-14', '2023-02-15', '2023-02-16',
#                '2023-02-17', '2023-02-18', '2023-02-19', '2023-02-20'],
#               dtype='datetime64[ns]', freq='D')

# %%
pd.date_range(start='2023-02-1', end='2023-02-20',freq='B')
# Out:
# DatetimeIndex(['2023-02-01', '2023-02-02', '2023-02-03', '2023-02-06',
#                '2023-02-07', '2023-02-08', '2023-02-09', '2023-02-10',
#                '2023-02-13', '2023-02-14', '2023-02-15', '2023-02-16',
#                '2023-02-17', '2023-02-20'],
#               dtype='datetime64[ns]', freq='B')

# %%
pd.date_range(start='2023-02-1', end='2023-02-20',freq='W')
# Out:
# DatetimeIndex(['2023-02-05', '2023-02-12', '2023-02-19'], dtype='datetime64[ns]', freq='W-SUN')

# %%
timeseries = pd.Series(pd.date_range(start='2023-02-1', end='2023-02-20',freq='D'))

# %%
timeseries.dt.day_name()
# Out:
# 0     Wednesday
# 1      Thursday
# 2        Friday
# 3      Saturday
# 4        Sunday
# 5        Monday
# 6       Tuesday
# 7     Wednesday
# 8      Thursday
# 9        Friday
# 10     Saturday
# 11       Sunday
# 12       Monday
# 13      Tuesday
# 14    Wednesday
# 15     Thursday
# 16       Friday
# 17     Saturday
# 18       Sunday
# 19       Monday
# dtype: object

# %%
! pip install pandas-datareader
# Out:
# ...
#      ------------------------------------ 109.5/109.5 kB 576.9 kB/s eta 0:00:00
# ...

# %%
import pandas_datareader as data

# %%
df_msft = data.DataReader(name='MSFT', data_source='stooq', start='2020-01-01', end='2023-01-01')

# %%
type(df_msft)
# Out:
# pandas.core.frame.DataFrame

# %%
df_msft.head()
# Out:
#               Open    High       Low   Close      Volume
# Date
# 2022-12-30  238.21  239.96  236.6600  239.82  21938472.0
# 2022-12-29  235.65  241.92  235.6500  241.01  19770693.0
# 2022-12-28  236.89  239.72  234.1700  234.53  17457104.0
# 2022-12-27  238.70  238.93  235.8300  236.96  16688648.0
# 2022-12-23  236.11  238.87  233.9428  238.73  21206982.0

# %%
df_msft['Date'] = df_msft.index

# %%
# total shares trade from mon to wed 
# hight val of stock placed in each year
# min closing val of each quarter in 2022

df_msft['Day'] = df_msft['Date'].dt.day_name()

# %%
# 1
df_msft.groupby('Day')['Volume'].sum()
# Out:
# Day
# Friday       1.631299e+09
# Monday       1.379890e+09
# Thursday     1.614756e+09
# Tuesday      1.589673e+09
# Wednesday    1.663333e+09
# Name: Volume, dtype: float64

# %%
# 2
df_msft.
